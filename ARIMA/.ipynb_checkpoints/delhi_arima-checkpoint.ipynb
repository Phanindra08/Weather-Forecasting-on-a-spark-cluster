# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
series=pd.Series.from_csv('required.csv',header=0)

# %%
series.head()
# Out:
# date
# 1996-11-01    53.0
# 1996-11-02    49.0
# 1996-11-03    56.0
# 1996-11-04    48.0
# 1996-11-05    29.0
# Name: hum, dtype: float64

# %%
series.plot()
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
plot_acf(series, lags=1000)

# %%
plot_pacf(series,lags=1000)

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
size = int(len(series) * 0.999)
train, test = series[0:size], series[size:len(series)]

# %%
print(test)
# Out:
# date
# 2017-04-17    38.0
# 2017-04-18    27.0
# 2017-04-19    24.0
# 2017-04-20    28.0
# 2017-04-21    39.0
# 2017-04-22    41.0
# 2017-04-23    28.0
# 2017-04-24    27.0
# Name: hum, dtype: float64

# %%
from sklearn.metrics import mean_squared_error

# %%
history = [x for x in train]
predictions = list()
for t in range(len(test)):
	model = ARIMA(history, order=(5,1,1))
	model_fit = model.fit(disp=0)
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot
#plt.plot(test)
#plt.plot(predictions, color='red')
#plt.show()
# Out:
# predicted=32.985237, expected=38.000000
# predicted=36.020335, expected=27.000000
# predicted=27.800867, expected=24.000000
# predicted=25.709682, expected=28.000000
# predicted=28.661303, expected=39.000000
# predicted=36.999822, expected=41.000000
# predicted=38.362815, expected=28.000000
# predicted=28.590058, expected=27.000000
# Test MSE: 44.877
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-54ae4d6fbe33> in <module>()
#      15 plt.plot(test)
#      16 plt.plot(predictions, color='red')
# ---> 17 plt.show()
#
# /usr/lib64/python2.7/site-packages/matplotlib/pyplot.pyc in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# /usr/lib/python2.7/site-packages/ipykernel/pylab/backend_inline.pyc in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# /usr/lib/python2.7/site-packages/ipykernel/pylab/backend_inline.pyc in _fetch_figure_metadata(fig)
#     177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
# --> 179                                 for label in axis.get_ticklabels()])
#     180         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     181             # there are one or more tick labels, all with the same lightness
#
# /usr/lib64/python2.7/site-packages/matplotlib/axis.pyc in get_ticklabels(self, minor, which)
#    1289         if minor:
#    1290             return self.get_minorticklabels()
# -> 1291         return self.get_majorticklabels()
#    1292
#    1293     def get_majorticklines(self):
#
# /usr/lib64/python2.7/site-packages/matplotlib/axis.pyc in get_majorticklabels(self)
#    1243     def get_majorticklabels(self):
#    1244         'Return a list of Text instances for the major ticklabels'
# -> 1245         ticks = self.get_major_ticks()
#    1246         labels1 = [tick.label1 for tick in ticks if tick.label1On]
#    1247         labels2 = [tick.label2 for tick in ticks if tick.label2On]
#
# /usr/lib64/python2.7/site-packages/matplotlib/axis.pyc in get_major_ticks(self, numticks)
#    1394         'get the tick instances; grow as necessary'
#    1395         if numticks is None:
# -> 1396             numticks = len(self.get_major_locator()())
#    1397
#    1398         while len(self.majorTicks) < numticks:
#
# /usr/lib64/python2.7/site-packages/matplotlib/dates.pyc in __call__(self)
#    1247     def __call__(self):
#    1248         'Return the locations of the ticks'
# -> 1249         self.refresh()
#    1250         return self._locator()
#    1251
#
# /usr/lib64/python2.7/site-packages/matplotlib/dates.pyc in refresh(self)
#    1267     def refresh(self):
#    1268         'Refresh internal information based on current limits.'
# -> 1269         dmin, dmax = self.viewlim_to_dt()
#    1270         self._locator = self.get_locator(dmin, dmax)
#    1271
#
# /usr/lib64/python2.7/site-packages/matplotlib/dates.pyc in viewlim_to_dt(self)
#    1024                              'often happens if you pass a non-datetime '
#    1025                              'value to an axis that has datetime units'
# -> 1026                              .format(vmin))
#    1027         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1028
#
# ValueError: view limit minimum -36822.15 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units
